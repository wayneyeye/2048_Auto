# %%
import sys,os
import concurrent.futures
import getpass
from selenium import webdriver #install selenium
from selenium.webdriver.common.keys import Keys
import time,random,string
#put geckodriver into the working directory
geckodriver_path=(os.path.join(os.getcwd(),'geckodriver-dir'))#this is wrong search path for modules
geckodriver_path=":"+geckodriver_path
os.environ["PATH"]+=geckodriver_path

# %%
#put geckodriver into the working directory
chromedriver_path=(os.path.join(os.getcwd(),'chrome'))#this is wrong search path for modules
chromedriver_path=":"+chromedriver_path
os.environ["PATH"]+=chromedriver_path

# %%
def current_status(driver):
    result={}
    for col in range(1,5):
        for row in range(1,5):
            key="c%d_r%d" %(col,row)
            try:
                tile=driver.find_element_by_class_name("tile-position-%d-%d" %(col,row))
                value=tile.find_element_by_class_name("tile-inner").text
                result[key]=int(value)
            except:
                result[key]=0
    return result
def get_score(driver):
    try:
        value=driver.find_element_by_class_name("score-container").text
        result=int(value)
    except:
        result=0
    return result

def game_over(driver):
    element=driver.find_element_by_class_name('game-message')
    display=element.value_of_css_property('display')
    return display=='none'

def game_retry(driver):
    retry_button=driver.find_element_by_class_name("retry-button")
    retry_button.click()

# %%
import copy
keymap={'up':Keys.ARROW_UP,
        'down':Keys.ARROW_DOWN,
        'left':Keys.ARROW_LEFT,
        'right':Keys.ARROW_RIGHT}
driver = webdriver.PhantomJS()
driver.get("https://wayneyeye.github.io/2048/")


driver_s = webdriver.PhantomJS()
driver_s.get("https://wayneyeye.github.io/2048_shadow/")

# %%
try_score={}
def shadow_and_try(driver_s,gameState,try_score,depth=1):
    try_score['Max']=0
    if not game_over(driver_s):
        score=get_score(driver_s)
        game_retry(driver_s)
        return score
    if depth==0: 
        score=get_score(driver_s)
        return score
    for move in ['up','down','left','right']:
#         print(move)
        try_score[move]={}
        js_stmt="new GameManager(4, KeyboardInputManager, HTMLActuator, LocalStorageManager,%s);" %gameState
        driver_s.execute_script(js_stmt)
#         print("reset")
#         time.sleep(5)
        driver_s.find_element_by_class_name('container').send_keys(keymap[move])
#         time.sleep(5)
        gameState2=driver_s.execute_script("return localStorage.gameState;")
        if gameState==gameState2:
#             print(gameState)
#             print(gameState2)
            continue
        try_score['Max']=max(shadow_and_try(driver_s,gameState2,try_score[move],depth=depth-1),try_score['Max'])
    return try_score['Max']

# %%
gameState=driver.execute_script("return localStorage.gameState;")

# %%
import pprint
try_score={}
gameState=driver.execute_script("return localStorage.gameState;")
shadow_and_try(driver_s,gameState,try_score,depth=3)
pprint.pprint(try_score)
# Out:
# {'Max': 64,
#  'down': {'Max': 36,
#           'down': {'Max': 0,
#                    'down': {'Max': 0},
#                    'left': {'Max': 0},
#                    'right': {'Max': 0},
#                    'up': {'Max': 0}},
#           'left': {'Max': 36,
#                    'down': {'Max': 0},
#                    'left': {'Max': 0},
#                    'right': {'Max': 0},
#                    'up': {'Max': 0}},
#           'right': {'Max': 0,
#                     'down': {'Max': 0},
#                     'left': {'Max': 0},
#                     'right': {'Max': 0},
#                     'up': {'Max': 0}},
#           'up': {'Max': 0,
#                  'down': {'Max': 0},
#                  'left': {'Max': 0},
#                  'right': {'Max': 0},
#                  'up': {'Max': 0}}},
#  'left': {'Max': 56,
#           'down': {'Max': 52,
#                    'down': {'Max': 0},
#                    'left': {'Max': 0},
#                    'right': {'Max': 0},
#                    'up': {'Max': 0}},
#           'left': {'Max': 52,
#                    'down': {'Max': 0},
#                    'left': {'Max': 0},
#                    'right': {'Max': 0},
#                    'up': {'Max': 0}},
#           'right': {'Max': 52,
#                     'down': {'Max': 0},
#                     'left': {'Max': 0},
#                     'right': {'Max': 0},
#                     'up': {'Max': 0}},
#           'up': {'Max': 56,
#                  'down': {'Max': 0},
#                  'left': {'Max': 0},
#                  'right': {'Max': 0},
#                  'up': {'Max': 0}}},
#  'right': {'Max': 64,
#            'down': {'Max': 52,
#                     'down': {'Max': 0},
#                     'left': {'Max': 0},
#                     'right': {'Max': 0},
#                     'up': {'Max': 0}},
#            'left': {'Max': 52,
#                     'down': {'Max': 0},
#                     'left': {'Max': 0},
#                     'right': {'Max': 0},
#                     'up': {'Max': 0}},
#            'right': {'Max': 52,
#                      'down': {'Max': 0},
#                      'left': {'Max': 0},
#                      'right': {'Max': 0},
#                      'up': {'Max': 0}},
#            'up': {'Max': 64,
#                   'down': {'Max': 0},
#                   'left': {'Max': 0},
#                   'right': {'Max': 0},
#                   'up': {'Max': 0}}},
#  'up': {'Max': 52,
#         'down': {'Max': 0,
#                  'down': {'Max': 0},
#                  'left': {'Max': 0},
#                  'right': {'Max': 0},
#                  'up': {'Max': 0}},
#         'left': {'Max': 52,
#                  'down': {'Max': 0},
#                  'left': {'Max': 0},
#                  'right': {'Max': 0},
#                  'up': {'Max': 0}},
#         'right': {'Max': 52,
#                   'down': {'Max': 0},
#                   'left': {'Max': 0},
#                   'right': {'Max': 0},
#                   'up': {'Max': 0}},
#         'up': {'Max': 0,
#                'down': {'Max': 0},
#                'left': {'Max': 0},
#                'right': {'Max': 0},
#                'up': {'Max': 0}}}}

# %%
driver.close()
driver_s.close()

# %%
def predit_next_move(try_score):
    ranklist=[]
    for move in ['up','down','left','right']:
        ranklist.append((move,try_score[move]['Max']))
    return sorted(ranklist, key=lambda movement: movement[1],reverse=True)

# %%
predit_next_move(try_score)
# Out:
# [('up', 20), ('left', 12), ('down', 4), ('right', 0)]

# %%
import copy
keymap={'up':Keys.ARROW_UP,
        'down':Keys.ARROW_DOWN,
        'left':Keys.ARROW_LEFT,
        'right':Keys.ARROW_RIGHT}
driver = webdriver.Firefox()
driver.get("https://wayneyeye.github.io/2048/")


while game_over(driver):
    driver_s = webdriver.PhantomJS()
    driver_s.get("https://wayneyeye.github.io/2048_shadow/")
    try_score={}
    gameState=driver.execute_script("return localStorage.gameState;")
    shadow_and_try(driver_s,gameState,try_score,depth=4)
    predict_move=predit_next_move(try_score)
    print(predict_move)
    driver_s.close()
    for j in range(4):
        print(predict_move[j][0])
        driver.find_element_by_class_name('container').send_keys(keymap[predict_move[j][0]])
        gameState2=driver.execute_script("return localStorage.gameState;")
        if gameState!=gameState2:
            break
        else:
            print("no improvement!")
# Out:
# [('left', 20), ('down', 12), ('up', 8), ('right', 8)]
# left
# [('right', 16), ('up', 8), ('down', 8), ('left', 0)]
# right
# [('up', 20), ('down', 20), ('right', 20), ('left', 16)]
# up
# [('up', 24), ('left', 24), ('right', 20), ('down', 16)]
# up
# [('up', 24), ('left', 24), ('right', 24), ('down', 20)]
# up
# [('left', 36), ('right', 28), ('up', 24), ('down', 24)]
# left
# [('up', 36), ('down', 32), ('left', 32), ('right', 24)]
# up
# [('left', 52), ('down', 36), ('right', 36), ('up', 8)]
# left
# [('down', 52), ('up', 40), ('right', 36), ('left', 28)]
# down
# [('up', 56), ('left', 56), ('right', 56), ('down', 40)]
# up
# [('left', 64), ('up', 48), ('down', 40), ('right', 40)]
# left
# [('right', 72), ('left', 68), ('up', 64), ('down', 56)]
# right
# [('right', 76), ('up', 72), ('left', 72), ('down', 68)]
# right
# [('up', 124), ('down', 120), ('right', 96), ('left', 76)]
# up
# [('left', 140), ('up', 136), ('down', 128), ('right', 104)]
# left
# [('left', 152), ('up', 136), ('down', 128), ('right', 128)]
# left
# [('up', 128), ('down', 128), ('left', 124), ('right', 92)]
# up
# [('right', 144), ('up', 140), ('left', 140), ('down', 128)]
# right
# [('left', 184), ('down', 144), ('up', 140), ('right', 140)]
# left
# [('up', 156), ('down', 156), ('left', 144), ('right', 140)]
# up
# [('left', 156), ('right', 152), ('down', 148), ('up', 144)]
# left
# [('right', 188), ('left', 164), ('up', 152), ('down', 152)]
# right
# [('right', 192), ('left', 156), ('down', 152), ('up', 4)]
# right
# no improvement!
# left
# [('left', 204), ('down', 176), ('right', 176), ('up', 172)]
# left
# no improvement!
# down
# [('right', 196), ('left', 192), ('down', 184), ('up', 180)]
# right
# [('down', 188), ('left', 180), ('up', 176), ('right', 176)]
# down
# [('up', 200), ('down', 184), ('right', 172), ('left', 164)]
# up
# [('right', 200), ('down', 188), ('left', 184), ('up', 8)]
# right
# [('left', 208), ('down', 192), ('up', 172), ('right', 164)]
# left
# [('down', 204), ('left', 204), ('up', 200), ('right', 176)]
# down
# [('left', 220), ('up', 204), ('down', 196), ('right', 180)]
# left
# [('left', 228), ('down', 220), ('up', 200), ('right', 192)]
# left
# [('left', 232), ('right', 216), ('down', 212), ('up', 208)]
# left
# [('down', 272), ('up', 232), ('right', 216), ('left', 212)]
# down
# [('left', 340), ('right', 280), ('up', 224), ('down', 0)]
# left
# [('up', 336), ('down', 280), ('right', 272), ('left', 240)]
# up
# [('left', 344), ('right', 336), ('down', 304), ('up', 12)]
# left
# [('right', 348), ('left', 344), ('up', 336), ('down', 332)]
# right
# [('left', 380), ('right', 372), ('down', 356), ('up', 352)]
# left
# [('left', 384), ('down', 380), ('up', 364), ('right', 348)]
# left
# [('left', 380), ('up', 376), ('down', 348), ('right', 348)]
# left
# [('up', 404), ('left', 380), ('right', 352), ('down', 348)]
# up
# [('right', 412), ('left', 384), ('down', 376), ('up', 12)]
# right
# [('up', 388), ('down', 388), ('right', 388), ('left', 384)]
# up
# [('right', 408), ('down', 384), ('left', 384), ('up', 380)]
# right
# [('down', 400), ('up', 392), ('left', 384), ('right', 8)]
# down
# [('right', 424), ('down', 404), ('left', 392), ('up', 388)]
# right
# [('down', 448), ('up', 444), ('right', 420), ('left', 412)]
# down
# [('left', 472), ('up', 460), ('down', 460), ('right', 428)]
# left
# [('down', 472), ('left', 464), ('right', 428), ('up', 424)]
# down
# [('right', 480), ('up', 460), ('down', 460), ('left', 460)]
# right
# [('right', 492), ('down', 476), ('up', 464), ('left', 432)]
# right
# no improvement!
# down
# [('left', 508), ('right', 488), ('up', 472), ('down', 464)]
# left
# [('down', 500), ('left', 484), ('up', 468), ('right', 468)]
# down
# [('left', 500), ('right', 492), ('up', 472), ('down', 472)]
# left
# [('down', 504), ('up', 500), ('right', 496), ('left', 488)]
# down
# [('right', 508), ('down', 500), ('up', 476), ('left', 0)]
# right
# [('right', 536), ('left', 484), ('up', 476), ('down', 24)]
# right
# no improvement!
# left
# [('left', 524), ('right', 508), ('up', 504), ('down', 504)]
# left
# [('up', 544), ('down', 488), ('left', 488), ('right', 488)]
# up
# [('left', 524), ('right', 516), ('down', 492), ('up', 488)]
# left
# [('right', 544), ('down', 516), ('left', 516), ('up', 496)]
# right
# [('right', 572), ('left', 552), ('up', 520), ('down', 516)]
# right
# no improvement!
# left
# [('down', 560), ('left', 544), ('up', 520), ('right', 520)]
# down
# [('up', 560), ('left', 536), ('down', 528), ('right', 520)]
# up
# [('left', 552), ('down', 544), ('up', 532), ('right', 524)]
# left
# [('right', 584), ('left', 580), ('up', 560), ('down', 0)]
# right
# [('right', 588), ('left', 572), ('down', 552), ('up', 28)]
# right
# [('left', 576), ('down', 552), ('up', 548), ('right', 548)]
# left
# [('down', 592), ('right', 564), ('up', 552), ('left', 552)]
# down
# [('right', 704), ('left', 584), ('up', 564), ('down', 560)]
# right
# [('up', 600), ('down', 600), ('left', 588), ('right', 576)]
# up
# [('right', 712), ('left', 616), ('up', 600), ('down', 0)]
# right
# [('down', 652), ('right', 652), ('up', 636), ('left', 0)]
# down
# [('left', 752), ('down', 704), ('up', 700), ('right', 672)]
# left
# [('down', 748), ('up', 716), ('right', 708), ('left', 0)]
# down
# [('left', 892), ('right', 892), ('down', 752), ('up', 688)]
# left
# [('left', 892), ('down', 880), ('right', 764), ('up', 760)]
# left
# [('right', 900), ('up', 896), ('left', 776), ('down', 760)]
# right
# [('right', 908), ('up', 892), ('left', 888), ('down', 772)]
# right
# no improvement!
# up
# [('right', 936), ('down', 904), ('up', 892), ('left', 768)]
# right
# no improvement!
# down
# [('up', 908), ('left', 904), ('right', 904), ('down', 896)]
# up
# [('down', 928), ('left', 908), ('right', 900), ('up', 16)]
# down
# [('down', 940), ('left', 936), ('right', 920), ('up', 908)]
# down
# [('down', 948), ('up', 912), ('right', 800), ('left', 776)]
# down
# no improvement!
# up
# [('down', 972), ('right', 940), ('left', 928), ('up', 920)]
# down
# [('up', 916), ('left', 808), ('right', 792), ('down', 0)]
# up
# [('left', 944), ('right', 940), ('down', 916), ('up', 20)]
# left
# [('down', 956), ('right', 952), ('up', 940), ('left', 940)]
# down
# [('down', 1016), ('right', 960), ('up', 952), ('left', 944)]
# down
# [('right', 1000), ('down', 984), ('up', 944), ('left', 0)]
# right
# [('down', 1076), ('up', 1068), ('right', 1000), ('left', 980)]
# down
# [('up', 1088), ('left', 1080), ('down', 1076), ('right', 1076)]
# up
# [('down', 1080), ('left', 1076), ('up', 1064), ('right', 1024)]
# down
# [('right', 1092), ('up', 1084), ('down', 1084), ('left', 1080)]
# right
# [('right', 1108), ('up', 1092), ('down', 1092), ('left', 1092)]
# right
# [('right', 1128), ('left', 1124), ('up', 1116), ('down', 16)]
# right
# no improvement!
# left
# [('up', 1112), ('down', 1112), ('left', 1100), ('right', 1100)]
# up
# [('left', 1120), ('down', 1116), ('right', 1112), ('up', 16)]
# left
# [('right', 1120), ('up', 1112), ('down', 1112), ('left', 1112)]
# right
# [('right', 1160), ('up', 1120), ('down', 1116), ('left', 1116)]
# right
# no improvement!
# up
# [('right', 1136), ('down', 1132), ('left', 1132), ('up', 1124)]
# right
# no improvement!
# down
# [('left', 1136), ('up', 1132), ('down', 1132), ('right', 1120)]
# left
# [('up', 1140), ('down', 1132), ('left', 1132), ('right', 1132)]
# up
# [('left', 1148), ('right', 1144), ('up', 1136), ('down', 1132)]
# left
# [('left', 1164), ('down', 1144), ('right', 1136), ('up', 8)]
# left
# no improvement!
# down
# [('left', 1168), ('right', 1152), ('down', 1148), ('up', 1144)]
# left
# [('down', 1152), ('up', 1144), ('right', 1144), ('left', 0)]
# down
# [('right', 1152), ('up', 1148), ('left', 1148), ('down', 1144)]
# right
# [('up', 1176), ('left', 1176), ('down', 1168), ('right', 1156)]
# up
# [('right', 1212), ('up', 1208), ('down', 1204), ('left', 1180)]
# right
# [('right', 1244), ('up', 1220), ('down', 1212), ('left', 1212)]
# right
# [('right', 1224), ('up', 1220), ('left', 1220), ('down', 0)]
# right
# [('up', 1236), ('left', 1224), ('down', 1220), ('right', 1220)]
# up
# [('right', 1264), ('up', 1260), ('down', 1228), ('left', 1224)]
# right
# no improvement!
# up
# [('up', 1236), ('left', 1232), ('down', 1228), ('right', 1224)]
# up
# [('down', 1236), ('left', 1236), ('right', 1236), ('up', 4)]
# down
# [('right', 1264), ('left', 1252), ('down', 1240), ('up', 1236)]
# right
# [('down', 1264), ('left', 1264), ('right', 1252), ('up', 1244)]
# down
# [('right', 1288), ('left', 1268), ('down', 1264), ('up', 1252)]
# right
# [('right', 1272), ('down', 1264), ('up', 1252), ('left', 1248)]
# right
# [('right', 1280), ('up', 1276), ('left', 1268), ('down', 20)]
# right
# [('down', 1292), ('up', 1280), ('left', 1280), ('right', 0)]
# down
# [('left', 1332), ('right', 1328), ('up', 1252), ('down', 0)]
# left
# [('left', 1344), ('down', 1328), ('up', 1300), ('right', 1296)]
# left
# no improvement!
# down
# [('left', 1344), ('down', 1328), ('right', 1328), ('up', 1296)]
# left
# [('up', 1340), ('down', 1340), ('left', 1340), ('right', 1336)]
# up
# [('right', 1356), ('left', 1344), ('down', 1340), ('up', 8)]
# right
# [('right', 1392), ('left', 1368), ('down', 1364), ('up', 1360)]
# right
# no improvement!
# left
# [('up', 1368), ('down', 1368), ('right', 1344), ('left', 0)]
# up
# [('right', 1392), ('up', 1372), ('down', 1364), ('left', 1360)]
# right
# [('left', 1404), ('down', 1376), ('up', 1372), ('right', 0)]
# left
# [('left', 1392), ('down', 1376), ('right', 1348), ('up', 4)]
# left
# no improvement!
# down
# [('down', 1384), ('left', 1384), ('up', 1380), ('right', 1380)]
# down
# [('right', 1396), ('left', 1392), ('up', 1380), ('down', 1380)]
# right
# [('down', 1396), ('up', 1392), ('left', 1388), ('right', 1384)]
# down
# [('left', 1412), ('down', 1400), ('up', 1392), ('right', 1392)]
# left
# [('up', 1420), ('left', 1408), ('down', 1404), ('right', 1392)]
# up
# [('down', 1492), ('up', 1424), ('left', 1424), ('right', 1420)]
# down
# [('left', 1444), ('down', 1428), ('up', 1424), ('right', 1420)]
# left
# [('right', 1480), ('up', 1420), ('left', 1416), ('down', 0)]
# right
# [('down', 1628), ('right', 1484), ('up', 1452), ('left', 0)]
# down
# [('up', 1620), ('left', 1436), ('right', 1436), ('down', 0)]
# up
# [('right', 1608), ('up', 1544), ('down', 1500), ('left', 1488)]
# right
# [('up', 1668), ('down', 1668), ('right', 1644), ('left', 1500)]
# up
# [('down', 1924), ('left', 1676), ('right', 1540), ('up', 8)]
# down
# [('left', 1968), ('down', 1964), ('up', 1628), ('right', 1576)]
# left
# [('up', 1680), ('right', 1640), ('left', 20), ('down', 16)]
# up
# [('down', 1532), ('right', 1512), ('left', 16), ('up', 8)]
# down
# [('left', 1568), ('right', 1540), ('down', 16), ('up', 0)]
# left
# [('down', 1636), ('up', 1552), ('right', 1540), ('left', 16)]
# down
# [('left', 1624), ('right', 1584), ('down', 1556), ('up', 1552)]
# left
# [('up', 1584), ('left', 12), ('down', 0), ('right', 0)]
# up
# [('down', 1592), ('right', 1560), ('left', 8), ('up', 4)]
# down
# [('right', 1656), ('down', 1640), ('up', 1612), ('left', 1552)]
# right
# [('down', 1628), ('left', 1628), ('up', 1616), ('right', 12)]
# down
# [('left', 1756), ('down', 1656), ('right', 1612), ('up', 1608)]
# left
# [('up', 1628), ('right', 1620), ('down', 20), ('left', 20)]
# up
# [('right', 1744), ('up', 1652), ('left', 1636), ('down', 1604)]
# right
# [('right', 2176), ('down', 2120), ('left', 2068), ('up', 1636)]
# right
# no improvement!
# down
# [('down', 1664), ('up', 1660), ('right', 1652), ('left', 0)]
# down
# [('left', 1692), ('right', 1684), ('up', 1680), ('down', 1676)]
# left
# [('up', 1700), ('right', 1688), ('left', 1684), ('down', 1668)]
# up
# [('right', 1960), ('down', 1668), ('up', 12), ('left', 0)]
# right
# [('down', 1888), ('left', 1820), ('up', 1760), ('right', 1728)]
# down
# [('left', 2160), ('right', 2160), ('down', 1768), ('up', 1760)]
# left
# [('left', 2176), ('down', 2164), ('up', 2152), ('right', 2148)]
# left
# [('down', 2216), ('up', 2212), ('left', 2180), ('right', 2144)]
# down
# [('right', 2208), ('down', 2176), ('left', 2168), ('up', 2160)]
# right
# [('down', 2216), ('left', 2180), ('up', 2164), ('right', 2156)]
# down
# [('left', 2248), ('up', 2188), ('down', 2168), ('right', 2160)]
# left
# [('left', 2264), ('right', 2252), ('down', 2236), ('up', 2216)]
# left
# [('left', 2256), ('right', 2240), ('down', 2220), ('up', 2200)]
# left
# [('left', 2264), ('right', 2240), ('down', 2220), ('up', 2200)]
# left
# no improvement!
# right
# [('right', 2388), ('left', 2252), ('down', 2220), ('up', 2196)]
# right
# no improvement!
# left
# [('down', 2240), ('up', 2212), ('right', 2204), ('left', 0)]
# down
# [('right', 2264), ('down', 2252), ('up', 2240), ('left', 0)]
# right
# [('right', 2272), ('up', 2264), ('down', 2248), ('left', 0)]
# right
# [('left', 2308), ('right', 2280), ('up', 2268), ('down', 2268)]
# left
# [('left', 2296), ('right', 2276), ('up', 2264), ('down', 2260)]
# left
# no improvement!
# right
# [('right', 2340), ('up', 2276), ('down', 2276), ('left', 2264)]
# right
# no improvement!
# up
# [('down', 2304), ('right', 2300), ('up', 2280), ('left', 2276)]
# down
# [('left', 2344), ('down', 2312), ('up', 2308), ('right', 2276)]
# left
# [('down', 2352), ('up', 2312), ('right', 2300), ('left', 2280)]
# down
# [('down', 2424), ('left', 2400), ('right', 2304), ('up', 2292)]
# down
# no improvement!
# left
# [('right', 2312), ('up', 2292), ('left', 24), ('down', 8)]
# right
# [('right', 2380), ('left', 2312), ('up', 2284), ('down', 12)]
# right
# [('left', 2372), ('down', 2332), ('up', 2292), ('right', 2292)]
# left
# [('up', 2416), ('right', 2300), ('left', 24), ('down', 4)]
# up
# [('right', 2640), ('left', 2584), ('down', 32), ('up', 16)]
# right
# [('left', 2316), ('down', 24), ('up', 16), ('right', 0)]
# left
# [('down', 2448), ('left', 2444), ('up', 2372), ('right', 24)]
# down
# [('right', 2556), ('left', 2376), ('up', 12), ('down', 0)]
# right
# [('right', 2568), ('up', 2444), ('down', 2376), ('left', 2364)]
# right
# [('left', 2592), ('down', 2588), ('right', 2584), ('up', 2576)]
# left
# [('up', 2392), ('right', 28), ('left', 16), ('down', 0)]
# up
# [('left', 2596), ('right', 2484), ('down', 24), ('up', 20)]
# left
# [('up', 2600), ('down', 2480), ('right', 2468), ('left', 2456)]
# up
# [('right', 2612), ('up', 2472), ('down', 2472), ('left', 0)]
# right
# [('right', 2644), ('down', 2632), ('up', 2608), ('left', 2600)]
# right
# no improvement!
# down
# [('down', 2644), ('right', 2640), ('up', 2628), ('left', 2628)]
# down
# no improvement!
# right
# [('right', 2660), ('left', 2640), ('down', 2636), ('up', 2632)]
# right
# [('right', 2720), ('left', 2696), ('down', 2676), ('up', 2640)]
# right
# no improvement!
# left
# [('up', 2660), ('down', 2660), ('left', 2640), ('right', 2636)]
# up
# [('up', 2692), ('down', 2656), ('right', 2656), ('left', 0)]
# up
# [('right', 2700), ('down', 2696), ('left', 2692), ('up', 8)]
# right
# [('up', 2704), ('left', 2704), ('down', 2700), ('right', 2700)]
# up
# [('right', 2704), ('down', 2700), ('left', 2700), ('up', 8)]
# right
# [('down', 2716), ('right', 2716), ('up', 2708), ('left', 2708)]
# down
# [('down', 2736), ('right', 2736), ('left', 2716), ('up', 2704)]
# down
# no improvement!
# right
# [('right', 2732), ('left', 2724), ('up', 2712), ('down', 2708)]
# right
# no improvement!
# left
# [('down', 2740), ('up', 2724), ('left', 2720), ('right', 2712)]
# down
# [('down', 2756), ('right', 2728), ('up', 2712), ('left', 16)]
# down
# no improvement!
# right
# [('down', 2744), ('up', 2740), ('right', 2724), ('left', 0)]
# down
# [('up', 2740), ('left', 2736), ('down', 2728), ('right', 2724)]
# up
# [('left', 2744), ('right', 2740), ('down', 2728), ('up', 8)]
# left
# [('up', 2748), ('right', 2740), ('left', 8), ('down', 0)]
# up
# [('down', 2824), ('right', 2808), ('left', 2780), ('up', 2764)]
# down
# [('left', 2780), ('down', 2768), ('right', 2764), ('up', 2760)]
# left
# [('left', 2792), ('down', 2772), ('right', 2768), ('up', 2764)]
# left
# [('up', 2796), ('right', 2780), ('left', 8), ('down', 0)]
# up
# [('left', 2884), ('right', 2876), ('down', 2868), ('up', 2780)]
# left
# [('left', 2904), ('right', 2892), ('up', 2816), ('down', 2816)]
# left
# [('up', 2908), ('left', 2904), ('down', 2900), ('right', 2880)]
# up
# [('left', 2912), ('down', 2896), ('right', 2896), ('up', 4)]
# left
# [('down', 2972), ('left', 2956), ('up', 2936), ('right', 2904)]
# down
# [('down', 2948), ('left', 2948), ('up', 2928), ('right', 2928)]
# down
# no improvement!
# left
# no improvement!
# up
# [('down', 3016), ('up', 2932), ('right', 2928), ('left', 2924)]
# down
# [('left', 2940), ('up', 2928), ('right', 2928), ('down', 2924)]
# left
# [('left', 2960), ('down', 2956), ('right', 2940), ('up', 2932)]
# left
# no improvement!
# down
# [('down', 2956), ('up', 2952), ('right', 2940), ('left', 0)]
# down
# [('up', 3000), ('left', 2980), ('right', 2960), ('down', 2956)]
# up
# [('right', 3040), ('left', 3020), ('down', 2996), ('up', 8)]
# right
# [('down', 2980), ('right', 2976), ('up', 12), ('left', 0)]
# down
# [('left', 2996), ('down', 2992), ('right', 2984), ('up', 2968)]
# left
# [('down', 2984), ('up', 2980), ('right', 2972), ('left', 8)]
# down
# no improvement!
# up
# [('left', 3008), ('up', 3004), ('right', 2992), ('down', 2976)]
# left
# no improvement!
# up
# [('left', 3004), ('down', 2992), ('right', 2992), ('up', 2980)]
# left
# [('up', 3016), ('down', 3000), ('left', 2992), ('right', 2988)]
# up
# [('right', 3068), ('left', 3008), ('down', 3000), ('up', 2988)]
# right
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-180-7c8ffa3e1db1> in <module>()
#      13     try_score={}
#      14     gameState=driver.execute_script("return localStorage.gameState;")
# ---> 15     shadow_and_try(driver_s,gameState,try_score,depth=4)
#      16     predict_move=predit_next_move(try_score)
#      17     print(predict_move)
#
# <ipython-input-178-25e2837fe9e7> in shadow_and_try(driver_s, gameState, try_score, depth)
#      23 #             print(gameState2)
#      24             continue
# ---> 25         try_score['Max']=max(shadow_and_try(driver_s,gameState2,try_score[move],depth=depth-1),try_score['Max'])
#      26     return try_score['Max']
#
# <ipython-input-178-25e2837fe9e7> in shadow_and_try(driver_s, gameState, try_score, depth)
#      23 #             print(gameState2)
#      24             continue
# ---> 25         try_score['Max']=max(shadow_and_try(driver_s,gameState2,try_score[move],depth=depth-1),try_score['Max'])
#      26     return try_score['Max']
#
# <ipython-input-178-25e2837fe9e7> in shadow_and_try(driver_s, gameState, try_score, depth)
#      23 #             print(gameState2)
#      24             continue
# ---> 25         try_score['Max']=max(shadow_and_try(driver_s,gameState2,try_score[move],depth=depth-1),try_score['Max'])
#      26     return try_score['Max']
#
# <ipython-input-178-25e2837fe9e7> in shadow_and_try(driver_s, gameState, try_score, depth)
#      13         try_score[move]={}
#      14         js_stmt="new GameManager(4, KeyboardInputManager, HTMLActuator, LocalStorageManager,%s);" %gameState
# ---> 15         driver_s.execute_script(js_stmt)
#      16 #         print("reset")
#      17 #         time.sleep(5)
#
# /home/yewenhe0904/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     489         return self.execute(command, {
#     490             'script': script,
# --> 491             'args': converted_args})['value']
#     492
#     493     def execute_async_script(self, script, *args):
#
# /home/yewenhe0904/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     254         response = self.command_executor.execute(driver_command, params)
#     255         if response:
# --> 256             self.error_handler.check_response(response)
#     257             response['value'] = self._unwrap_value(
#     258                 response.get('value', None))
#
# /home/yewenhe0904/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: {"errorMessage":"Can't find variable: None","request":{"headers":{"Accept":"application/json","Accept-Encoding":"identity","Connection":"close","Content-Length":"160","Content-Type":"application/json;charset=UTF-8","Host":"127.0.0.1:34415","User-Agent":"Python http auth"},"httpVersion":"1.1","method":"POST","post":"{\"script\": \"new GameManager(4, KeyboardInputManager, HTMLActuator, LocalStorageManager,None);\", \"args\": [], \"sessionId\": \"c18aae90-6b70-11e7-b255-111e39591748\"}","url":"/execute","urlParsed":{"anchor":"","query":"","file":"execute","directory":"/","path":"/execute","relative":"/execute","port":"","host":"","password":"","user":"","userInfo":"","authority":"","protocol":"","source":"/execute","queryKey":{},"chunks":["execute"]},"urlOriginal":"/session/c18aae90-6b70-11e7-b255-111e39591748/execute"}}
# Screenshot: available via screen
