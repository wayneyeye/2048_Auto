# %%
def next_move(desired, priority):
    import random
    choice=['up','down','left','right']
    choice.remove(desired)
    chance_not_desired=(1-priority)/4
    cut_values=[priority+chance_not_desired,priority+2*chance_not_desired,priority+3*chance_not_desired]
#     print(cut_values)
    dice=random.random()
    if dice<=cut_values[0]:
        return desired
    elif dice<=cut_values[1]:
        return choice[0]
    elif dice<=cut_values[2]:
        return choice[1]
    else:
        return choice[2]

def game_over(driver):
    element=driver.find_element_by_class_name('game-message')
    display=element.value_of_css_property('display')
    return display=='none'
def game_retry(driver):
    retry_button=driver.find_element_by_class_name("retry-button")
    retry_button.click()

def current_status(driver):
    result={}
    for col in range(1,5):
        for row in range(1,5):
            key="c%d_r%d" %(col,row)
            try:
                tile=driver.find_element_by_class_name("tile-position-%d-%d" %(col,row))
                value=tile.find_element_by_class_name("tile-inner").text
                result[key]=int(value)
            except:
                result[key]=0
    return result
def submit_step(step,record,skip=False):
    if skip:
        flag=True
        if len(record)==0:
            record.append(step)
        else:
            for col in range(1,5):
                if flag==False:
                    break
                for row in range(1,5):
                    key="c%d_r%d" %(col,row)
                    if step[key]!=record[-1][key]:
                        flag=False
                        break
            if flag==False:
                record.append(step)
    else:
        record.append(step)
        
def get_max_score(record):
    grid=[]
    score=0
    for col in range(1,5):
        for row in range(1,5):
            key="c%d_r%d" %(col,row)
            try:
                grid.append(record[-1][key])
            except:
                grid.append(0)
    score=max(grid)
    return (score)

def submit_record(record,password):
    current_round_score=get_max_score(record)
    for s in record:
        insert_step_in_db(s,current_round_score,password)
def find_cut_val(step,div):
    return(max(1,max(step['c1_r1'],step['c1_r2'],step['c1_r3'],step['c1_r4'],
                         step['c2_r1'],step['c2_r2'],step['c2_r3'],step['c2_r4'],
                         step['c3_r1'],step['c3_r2'],step['c3_r3'],step['c3_r4'],
                         step['c4_r1'],step['c4_r2'],step['c4_r3'],step['c4_r4'])/div))
            
def find_step_expected(step,password,cut=1):
    step2=step.copy()
    for col in range(1,5):
        for row in range(1,5):
            key="c%d_r%d" %(col,row)
            if step2[key]<=cut and step2[key]>0:
                step2[key]=0
    import pymysql
    connection=pymysql.connect(host="192.168.1.188",user="yewenhe0904",passwd=password,db='a2048')
    try:
        with connection.cursor() as cursor:
            sql='''SELECT move, AVG(expected_score) as exp FROM testing_v2
            WHERE '''
            stmt=''
            for col in range(1,5):
                for row in range(1,5):
                    key="c%d_r%d" %(col,row)
                    if step[key]<=cut and step[key]>0:
                        p=(" %s>%%s AND" % key)
                    else:
                        p=(" %s=%%s AND" % key)
                    stmt+=p
            stmt+=' 1=1'
            sql=sql+stmt
            sql+=' GROUP BY move ORDER BY 2 DESC'
            condition=(step2['c1_r1'],step2['c1_r2'],step2['c1_r3'],step2['c1_r4'],
                         step2['c2_r1'],step2['c2_r2'],step2['c2_r3'],step2['c2_r4'],
                         step2['c3_r1'],step2['c3_r2'],step2['c3_r3'],step2['c3_r4'],
                         step2['c4_r1'],step2['c4_r2'],step2['c4_r3'],step2['c4_r4'])
            cursor.execute(sql,condition)
            result=cursor.fetchall()
    finally:
        connection.close()           
    return(result)
            
def insert_step_in_db(step,score,password):
    import pymysql
    connection=pymysql.connect(host="192.168.1.188",user="yewenhe0904",passwd=password,db='a2048')
    try:
        with connection.cursor() as cursor:
            sql='''INSERT INTO testing_v2
            VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s) '''
            condition=(step['c1_r1'],step['c1_r2'],step['c1_r3'],step['c1_r4'],
                         step['c2_r1'],step['c2_r2'],step['c2_r3'],step['c2_r4'],
                         step['c3_r1'],step['c3_r2'],step['c3_r3'],step['c3_r4'],
                         step['c4_r1'],step['c4_r2'],step['c4_r3'],step['c4_r4'],
                       step['move'],score)
            cursor.execute(sql,condition)
        connection.commit()
    finally:
        connection.close()

# %%
password='k2cxtrb64vi'
step_detail={'c1_r1': 2, 'c1_r2': 0, 'c1_r3': 0, 'c1_r4': 0, 'c2_r1': 0, 'c2_r2': 0, 'c2_r3': 0, 'c2_r4': 0, 'c3_r1': 4, 'c3_r2': 0, 'c3_r3': 0, 'c3_r4': 0, 'c4_r1': 2, 'c4_r2': 4, 'c4_r3': 2, 'c4_r4': 0, 'move': 'right'}
print(step_detail)
find_step_expected(step_detail,password,cut=8)
# Out:
# {'c1_r1': 2, 'c1_r2': 0, 'c1_r3': 0, 'c1_r4': 0, 'c2_r1': 0, 'c2_r2': 0, 'c2_r3': 0, 'c2_r4': 0, 'c3_r1': 4, 'c3_r2': 0, 'c3_r3': 0, 'c3_r4': 0, 'c4_r1': 2, 'c4_r2': 4, 'c4_r3': 2, 'c4_r4': 0, 'move': 'right'}
# (('up', 146.28571428571428),
#  ('right', 114.28571428571429),
#  ('down', 89.6),
#  ('left', 83.2))

# %%
#worker function
def play_2048(db_password,retry=1,obeyance=0):
    #check db connection
    import pymysql
    try:
        connection=pymysql.connect(host="192.168.1.188",user="yewenhe0904",passwd=db_password,db='a2048')
    except:
        print("Problems in DB Connection!\nQuit...")
        sys.exit(1)
    from selenium import webdriver #install selenium
    from selenium.webdriver.common.keys import Keys
    import time,random,string
    print("Worker (PID=%s) Started" % os.getpid())
    keymap={'up':Keys.ARROW_UP,
        'down':Keys.ARROW_DOWN,
        'left':Keys.ARROW_LEFT,
        'right':Keys.ARROW_RIGHT}
    driver = webdriver.Firefox()
    driver.get("https://wayneyeye.github.io/2048/")
    elem = driver.find_element_by_class_name('game-container')
    password=db_password
    for i in range(retry):
        record=[]
        while game_over(driver):
            step_detail=current_status(driver)
            cut=find_cut_val(step_detail,32)
            step_pred=find_step_expected(step_detail,password,cut)
            if len(step_pred)>0:
                move_pred=step_pred[0][0]
                key=next_move(move_pred,obeyance)
                print("Worker (PID=%s) Round %s Matched! ---- %s" % (os.getpid(),i+1,key))
            else:
                key=random.choice(('up','down','left','right'))
            step_detail["move"]=key
            elem.send_keys(keymap[key])
            submit_step(step_detail,record,skip=True)
        game_retry(driver)
        print("Worker (PID=%s) Round %s Submitting Scores" % (os.getpid(),i+1))
        submit_record(record,password=password)
        print("Worker (PID=%s) Round %s Highest Score: %s" % (os.getpid(),i+1,get_max_score(record)))
    driver.close()
    print("Worker (PID=%s) Closed" % os.getpid())

# %%
import termios, sys, os
TERMIOS = termios

def getkey():
    fd = sys.stdin.fileno()
    old = termios.tcgetattr(fd)
    new = termios.tcgetattr(fd)
    new[3] = new[3] & ~TERMIOS.ICANON & ~TERMIOS.ECHO
    new[6][TERMIOS.VMIN] = 1
    new[6][TERMIOS.VTIME] = 0
    termios.tcsetattr(fd, TERMIOS.TCSANOW, new)
    c = None
    try:
        c = os.read(fd, 1)
    finally:
        termios.tcsetattr(fd, TERMIOS.TCSAFLUSH, old)
    return c

# %%
#worker function
def play_2048_human(db_password,retry=1,obeyance=0):
    #check db connection
    import pymysql
    try:
        connection=pymysql.connect(host="192.168.1.188",user="yewenhe0904",passwd=db_password,db='a2048')
    except:
        print("Problems in DB Connection!\nQuit...")
        sys.exit(1)
    from selenium import webdriver #install selenium
    from selenium.webdriver.common.keys import Keys
    import time,random,string
    print("Worker (PID=%s) Started" % os.getpid())
    keymap={'up':Keys.ARROW_UP,
        'down':Keys.ARROW_DOWN,
        'left':Keys.ARROW_LEFT,
        'right':Keys.ARROW_RIGHT}
    driver = webdriver.Firefox()
    driver.get("https://wayneyeye.github.io/2048/")
    elem = driver.find_element_by_class_name('game-container')
    password=db_password
    for i in range(retry):
        record=[]
        while game_over(driver):
            step_detail=current_status(driver)
            x = getkey()
            if x == "w":
                key='up'
            if x == "a":
                key='left'
            if x == "s":
                key='down'
            if x == "d":
                key='right'
            step_detail["move"]=key
            elem.send_keys(keymap[key])
            submit_step(step_detail,record,skip=True)
        game_retry(driver)
        print("Worker (PID=%s) Round %s Submitting Scores" % (os.getpid(),i+1))
        submit_record(record,password=password)
        print("Worker (PID=%s) Round %s Highest Score: %s" % (os.getpid(),i+1,get_max_score(record)))
    driver.close()
    print("Worker (PID=%s) Closed" % os.getpid())

# %%
if __name__ == '__main__':
    import sys,os
    #put geckodriver into the working directory
    geckodriver_path=(os.path.join(os.getcwd(),'geckodriver-dir'))#this is wrong search path for modules
    geckodriver_path=":"+geckodriver_path
    os.environ["PATH"]+=geckodriver_path
    import concurrent.futures
    import getpass
    password=getpass.getpass("DB password? ")
    play_2048_human(password,1,0.97)
# Out:
# DB password? ········
# Worker (PID=25134) Started
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-20-d4c4c53d6cc7> in <module>()
#       8     import getpass
#       9     password=getpass.getpass("DB password? ")
# ---> 10     play_2048_human(password,1,0.97)
#
# <ipython-input-17-c4ce2f5237d7> in play_2048_human(db_password, retry, obeyance)
#      24         while game_over(driver):
#      25             step_detail=current_status(driver)
# ---> 26             x = getkey()
#      27             if x == "w":
#      28                 key='up'
#
# <ipython-input-19-62385075d574> in getkey()
#       4 def getkey():
#       5     fd = sys.stdin.fileno()
# ----> 6     old = termios.tcgetattr(fd)
#       7     new = termios.tcgetattr(fd)
#       8     new[3] = new[3] & ~TERMIOS.ICANON & ~TERMIOS.ECHO
#
# error: (25, 'Inappropriate ioctl for device')

# %%
if __name__ == '__main__':
    import sys,os
    #put geckodriver into the working directory
    geckodriver_path=(os.path.join(os.getcwd(),'geckodriver-dir'))#this is wrong search path for modules
    geckodriver_path=":"+geckodriver_path
    os.environ["PATH"]+=geckodriver_path
    import concurrent.futures
    import getpass
    password=getpass.getpass("DB password? ")
    worker_n=int(input("Number of workers?"))
    worker_retrys=[]
    for i in range(worker_n):
        worker_retrys.append(int(input("Retry for worker %s?" %i)))   
    for o in range(0,75,5):
        print("obeyance = %s" %o)
        with concurrent.futures.ProcessPoolExecutor(worker_n+2) as executor:
            for retry_n in worker_retrys:
                executor.submit(play_2048,password,retry_n,o/100)
# Out:
# DB password? ········
# Number of workers?2
# Retry for worker 0?1
# Retry for worker 1?1
# obeyance = 0
# Worker (PID=17809) Started
# Worker (PID=17810) Started
# Worker (PID=17810) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17810) Round 1 Submitting Scores
# Worker (PID=17810) Round 1 Highest Score: 64
# Worker (PID=17810) Closed
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- right
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Matched! ---- left
# Worker (PID=17809) Round 1 Matched! ---- up
# Worker (PID=17809) Round 1 Matched! ---- down
# Worker (PID=17809) Round 1 Submitting Scores
# Worker (PID=17809) Round 1 Highest Score: 256
# Worker (PID=17809) Closed
# obeyance = 5
# Worker (PID=18106) Started
# Worker (PID=18107) Started
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- up
# Worker (PID=18106) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- up
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18106) Round 1 Submitting Scores
# Worker (PID=18106) Round 1 Highest Score: 32
# Worker (PID=18106) Closed
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- up
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- up
# Worker (PID=18107) Round 1 Matched! ---- left
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- up
# Worker (PID=18107) Round 1 Matched! ---- down
# Worker (PID=18107) Round 1 Matched! ---- left
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- right
# Worker (PID=18107) Round 1 Matched! ---- left
# Worker (PID=18107) Round 1 Matched! ---- left
# Worker (PID=18107) Round 1 Matched! ---- left
# Worker (PID=18107) Round 1 Matched! ---- up
# Worker (PID=18107) Round 1 Submitting Scores
# Worker (PID=18107) Round 1 Highest Score: 128
# Worker (PID=18107) Closed
# obeyance = 10
# Worker (PID=18343) Started
# Worker (PID=18345) Started
# Worker (PID=18345) Round 1 Matched! ---- up
# Worker (PID=18343) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- left
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- left
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18343) Round 1 Matched! ---- left
# Worker (PID=18343) Round 1 Matched! ---- up
# Worker (PID=18343) Round 1 Matched! ---- left
# Worker (PID=18343) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18343) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- up
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- left
# Worker (PID=18345) Round 1 Matched! ---- left
# Worker (PID=18345) Round 1 Matched! ---- left
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18345) Round 1 Matched! ---- left
# Worker (PID=18343) Round 1 Submitting Scores
# Worker (PID=18345) Round 1 Matched! ---- right
# Worker (PID=18345) Round 1 Matched! ---- down
# Worker (PID=18343) Round 1 Highest Score: 128
# Worker (PID=18343) Closed
# Worker (PID=18345) Round 1 Submitting Scores
# Worker (PID=18345) Round 1 Highest Score: 256
# Worker (PID=18345) Closed
# obeyance = 15
# Worker (PID=18605) Started
# Worker (PID=18606) Started
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18605) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18605) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- up
# Worker (PID=18605) Round 1 Matched! ---- up
# Worker (PID=18605) Round 1 Matched! ---- up
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18605) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18605) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- down
# Worker (PID=18606) Round 1 Matched! ---- down
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Matched! ---- up
# Worker (PID=18606) Round 1 Matched! ---- up
# Worker (PID=18605) Round 1 Matched! ---- up
# Worker (PID=18606) Round 1 Matched! ---- up
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18606) Round 1 Matched! ---- up
# Worker (PID=18606) Round 1 Matched! ---- up
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18606) Round 1 Matched! ---- down
# Worker (PID=18606) Round 1 Matched! ---- left
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18606) Round 1 Matched! ---- down
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18606) Round 1 Matched! ---- left
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18606) Round 1 Matched! ---- left
# Worker (PID=18606) Round 1 Matched! ---- up
# Worker (PID=18606) Round 1 Matched! ---- right
# Worker (PID=18606) Round 1 Matched! ---- down
# Worker (PID=18606) Round 1 Submitting Scores
# Worker (PID=18606) Round 1 Highest Score: 128
# Worker (PID=18606) Closed
# Worker (PID=18605) Round 1 Matched! ---- left
# Worker (PID=18605) Round 1 Matched! ---- up
# Worker (PID=18605) Round 1 Matched! ---- right
# Worker (PID=18605) Round 1 Submitting Scores
# Worker (PID=18605) Round 1 Highest Score: 256
# Worker (PID=18605) Closed
# obeyance = 20
# Worker (PID=18880) Started
# Worker (PID=18881) Started
# Worker (PID=18881) Round 1 Matched! ---- right
# Worker (PID=18881) Round 1 Matched! ---- down
# Worker (PID=18881) Round 1 Matched! ---- right
# Worker (PID=18881) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- left
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- down
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- left
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- left
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- left
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- up
# Worker (PID=18881) Round 1 Matched! ---- left
# Worker (PID=18880) Round 1 Matched! ---- down
# Worker (PID=18880) Round 1 Matched! ---- down
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18881) Round 1 Submitting Scores
# Worker (PID=18880) Round 1 Matched! ---- right
# Worker (PID=18880) Round 1 Matched! ---- left
# Worker (PID=18881) Round 1 Highest Score: 128
# Worker (PID=18881) Closed
# Worker (PID=18880) Round 1 Submitting Scores
# Worker (PID=18880) Round 1 Highest Score: 256
# Worker (PID=18880) Closed
# obeyance = 25
# Worker (PID=19150) Started
# Worker (PID=19148) Started
# Worker (PID=19148) Round 1 Matched! ---- down
# Worker (PID=19148) Round 1 Matched! ---- left
# Worker (PID=19148) Round 1 Matched! ---- right
# Worker (PID=19148) Round 1 Matched! ---- left
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- right
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- left
# Worker (PID=19150) Round 1 Matched! ---- left
# Worker (PID=19150) Round 1 Matched! ---- left
# Worker (PID=19150) Round 1 Matched! ---- left
# Worker (PID=19150) Round 1 Matched! ---- right
# Worker (PID=19150) Round 1 Matched! ---- up
# Worker (PID=19150) Round 1 Matched! ---- left
# Worker (PID=19148) Round 1 Matched! ---- right
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- right
# Worker (PID=19150) Round 1 Matched! ---- right
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- up
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- left
# Worker (PID=19148) Round 1 Submitting Scores
# Worker (PID=19148) Round 1 Highest Score: 64
# Worker (PID=19148) Closed
# Worker (PID=19150) Round 1 Matched! ---- down
# Worker (PID=19150) Round 1 Matched! ---- up
# Worker (PID=19150) Round 1 Submitting Scores
# Worker (PID=19150) Round 1 Highest Score: 256
# Worker (PID=19150) Closed
# obeyance = 30
# Worker (PID=19397) Started
# Worker (PID=19396) Started
# Worker (PID=19396) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19396) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19396) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19396) Round 1 Matched! ---- down
# Worker (PID=19396) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19396) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19396) Round 1 Submitting Scores
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19396) Round 1 Highest Score: 128
# Worker (PID=19396) Closed
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- left
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- down
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- up
# Worker (PID=19397) Round 1 Matched! ---- right
# Worker (PID=19397) Round 1 Submitting Scores
# Worker (PID=19397) Round 1 Highest Score: 256
# Worker (PID=19397) Closed
# obeyance = 35
# Worker (PID=19796) Started
# Worker (PID=19797) Started
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19797) Round 1 Matched! ---- right
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- left
# Worker (PID=19797) Round 1 Matched! ---- left
# Worker (PID=19797) Round 1 Matched! ---- up
# Worker (PID=19797) Round 1 Matched! ---- left
# Worker (PID=19797) Round 1 Matched! ---- up
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- up
# Worker (PID=19797) Round 1 Matched! ---- left
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- up
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- up
# Worker (PID=19797) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- left
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- up
# Worker (PID=19797) Round 1 Matched! ---- right
# Worker (PID=19797) Round 1 Matched! ---- right
# Worker (PID=19797) Round 1 Matched! ---- left
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- left
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19797) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- up
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- left
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- up
# Worker (PID=19796) Round 1 Matched! ---- down
# Worker (PID=19796) Round 1 Matched! ---- right
# Worker (PID=19796) Round 1 Matched! ---- left
# Worker (PID=19796) Round 1 Submitting Scores
# Worker (PID=19796) Round 1 Highest Score: 128
# Worker (PID=19796) Closed
# Worker (PID=19797) Round 1 Submitting Scores
# Worker (PID=19797) Round 1 Highest Score: 128
# Worker (PID=19797) Closed
# obeyance = 40
# Worker (PID=20084) Started
# Worker (PID=20083) Started
# Worker (PID=20084) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- up
# Worker (PID=20084) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- down
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- down
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20084) Round 1 Matched! ---- up
# Worker (PID=20084) Round 1 Submitting Scores
# Worker (PID=20084) Round 1 Highest Score: 64
# Worker (PID=20084) Closed
# Worker (PID=20083) Round 1 Matched! ---- down
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- down
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- up
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- down
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- up
# Worker (PID=20083) Round 1 Matched! ---- up
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- right
# Worker (PID=20083) Round 1 Matched! ---- left
# Worker (PID=20083) Round 1 Matched! ---- up
# Worker (PID=20083) Round 1 Submitting Scores
# Worker (PID=20083) Round 1 Highest Score: 128
# Worker (PID=20083) Closed
# obeyance = 45
# Worker (PID=20336) Started
# Worker (PID=20335) Started
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- right
# Worker (PID=20335) Round 1 Matched! ---- right
# Worker (PID=20335) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20335) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20335) Round 1 Matched! ---- right
# Worker (PID=20335) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20335) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20335) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Matched! ---- left
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20335) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Matched! ---- right
# Worker (PID=20335) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20336) Round 1 Matched! ---- down
# Worker (PID=20335) Round 1 Submitting Scores
# Worker (PID=20336) Round 1 Matched! ---- down
# Worker (PID=20336) Round 1 Matched! ---- down
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20335) Round 1 Highest Score: 64
# Worker (PID=20335) Closed
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20336) Round 1 Matched! ---- down
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- down
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- left
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- down
# Worker (PID=20336) Round 1 Matched! ---- up
# Worker (PID=20336) Round 1 Matched! ---- right
# Worker (PID=20336) Round 1 Submitting Scores
# Worker (PID=20336) Round 1 Highest Score: 128
# Worker (PID=20336) Closed
# obeyance = 50
# Worker (PID=20632) Started
# Worker (PID=20633) Started
# Worker (PID=20633) Round 1 Matched! ---- left
# Worker (PID=20632) Round 1 Matched! ---- down
# Worker (PID=20633) Round 1 Matched! ---- up
# Worker (PID=20632) Round 1 Matched! ---- down
# Worker (PID=20632) Round 1 Submitting Scores
# Worker (PID=20632) Round 1 Highest Score: 32
# Worker (PID=20632) Closed
# Worker (PID=20633) Round 1 Matched! ---- down
# Worker (PID=20633) Round 1 Matched! ---- left
# Worker (PID=20633) Round 1 Submitting Scores
# Worker (PID=20633) Round 1 Highest Score: 64
# Worker (PID=20633) Closed
# obeyance = 55
# Worker (PID=20834) Started
# Worker (PID=20835) Started
# Worker (PID=20834) Round 1 Matched! ---- down
# Worker (PID=20835) Round 1 Matched! ---- down
# Worker (PID=20834) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20834) Round 1 Matched! ---- up
# Worker (PID=20834) Round 1 Matched! ---- right
# Worker (PID=20834) Round 1 Matched! ---- left
# Worker (PID=20834) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- down
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20834) Round 1 Matched! ---- down
# Worker (PID=20834) Round 1 Matched! ---- left
# Worker (PID=20834) Round 1 Matched! ---- left
# Worker (PID=20834) Round 1 Matched! ---- up
# Worker (PID=20834) Round 1 Matched! ---- right
# Worker (PID=20834) Round 1 Matched! ---- right
# Worker (PID=20834) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20834) Round 1 Matched! ---- up
# Worker (PID=20834) Round 1 Matched! ---- up
# Worker (PID=20834) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- down
# Worker (PID=20834) Round 1 Submitting Scores
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20834) Round 1 Highest Score: 64
# Worker (PID=20834) Closed
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- down
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- right
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- left
# Worker (PID=20835) Round 1 Matched! ---- down
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Matched! ---- up
# Worker (PID=20835) Round 1 Submitting Scores
# Worker (PID=20835) Round 1 Highest Score: 128
# Worker (PID=20835) Closed
# obeyance = 60
# Worker (PID=21117) Started
# Worker (PID=21115) Started
# Worker (PID=21117) Round 1 Matched! ---- down
# Worker (PID=21115) Round 1 Matched! ---- down
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- up
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- down
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- down
# Worker (PID=21115) Round 1 Matched! ---- right
# Worker (PID=21115) Round 1 Matched! ---- down
# Worker (PID=21115) Round 1 Matched! ---- right
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21115) Round 1 Matched! ---- right
# Worker (PID=21115) Round 1 Matched! ---- up
# Worker (PID=21115) Round 1 Matched! ---- down
# Worker (PID=21115) Round 1 Matched! ---- up
# Worker (PID=21115) Round 1 Matched! ---- left
# Worker (PID=21117) Round 1 Submitting Scores
# Worker (PID=21117) Round 1 Highest Score: 64
# Worker (PID=21117) Closed
# Worker (PID=21115) Round 1 Submitting Scores
# Worker (PID=21115) Round 1 Highest Score: 128
# Worker (PID=21115) Closed
# obeyance = 65
# Worker (PID=21356) Started
# Worker (PID=21358) Started
# Worker (PID=21358) Round 1 Matched! ---- down
# Worker (PID=21356) Round 1 Matched! ---- right
# Worker (PID=21356) Round 1 Matched! ---- right
# Worker (PID=21358) Round 1 Matched! ---- left
# Worker (PID=21356) Round 1 Matched! ---- up
# Worker (PID=21358) Round 1 Matched! ---- left
# Worker (PID=21358) Round 1 Submitting Scores
# Worker (PID=21358) Round 1 Highest Score: 64
# Worker (PID=21358) Closed
# Worker (PID=21356) Round 1 Matched! ---- down
# Worker (PID=21356) Round 1 Matched! ---- up
# Worker (PID=21356) Round 1 Matched! ---- left
# Worker (PID=21356) Round 1 Matched! ---- down
# Worker (PID=21356) Round 1 Matched! ---- left
# Worker (PID=21356) Round 1 Matched! ---- up
# Worker (PID=21356) Round 1 Matched! ---- up
# Worker (PID=21356) Round 1 Matched! ---- right
# Worker (PID=21356) Round 1 Submitting Scores
# Worker (PID=21356) Round 1 Highest Score: 128
# Worker (PID=21356) Closed
# obeyance = 70
# Worker (PID=21568) Started
# Worker (PID=21569) Started
# Worker (PID=21568) Round 1 Matched! ---- left
# Worker (PID=21568) Round 1 Matched! ---- down
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21568) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- down
# Worker (PID=21568) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21568) Round 1 Matched! ---- down
# Worker (PID=21568) Round 1 Matched! ---- left
# Worker (PID=21568) Round 1 Matched! ---- down
# Worker (PID=21568) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- down
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21568) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- down
# Worker (PID=21569) Round 1 Matched! ---- left
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- down
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21568) Round 1 Matched! ---- left
# Worker (PID=21569) Round 1 Matched! ---- down
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Submitting Scores
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- left
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21568) Round 1 Highest Score: 128
# Worker (PID=21568) Closed
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- left
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- right
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- up
# Worker (PID=21569) Round 1 Matched! ---- left
# Worker (PID=21569) Round 1 Submitting Scores
# Worker (PID=21569) Round 1 Highest Score: 128
# Worker (PID=21569) Closed

# %%
for o in range(0,75,5):
    print(o/100)
# Out:
# 0.0
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
